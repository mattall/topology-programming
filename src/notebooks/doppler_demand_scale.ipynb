# %%
from onset.utilities.plotters import *
from io import StringIO

# %%
df = pd.read_csv("data/reports/summary.csv")

# %%
sns.scatterplot(df, x="Demand Scale", y="Total Solutions")
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Total Solutions'>

# %%
sns.scatterplot(df, x="Demand Scale", y=" Max Link Utilization")
# Out:
# <Axes: xlabel='Demand Scale', ylabel=' Max Link Utilization'>

# %%
df["Total Solutions"][:14]
# Out:
# 0     994
# 1     999
# 2     984
# 3     988
# 4     996
# 5     991
# 6     990
# 7     987
# 8     993
# 9     929
# 10    981
# 11    698
# 12    640
# 13    800
# Name: Total Solutions, dtype: int64

# %%
np.std(df["Total Solutions"][:14])
# Out:
# 116.8880504009311

# %%
df["Demand Scale"][:14]
# Out:
# 0     0.1
# 1     0.3
# 2     0.4
# 3     0.5
# 4     0.6
# 5     0.7
# 6     0.8
# 7     0.9
# 8     1.0
# 9     1.1
# 10    1.2
# 11    1.3
# 12    1.4
# 13    1.5
# Name: Demand Scale, dtype: float64

# %%
np.std(df["Demand Scale"][:14])
# Out:
# 0.41526976724996095

# %%
df[" Max Link Utilization"][:14]
# Out:
# 0     0.192870
# 1     0.578611
# 2     0.771482
# 3     0.482176
# 4     0.672720
# 5     0.675046
# 6     0.771482
# 7     0.578611
# 8     0.718644
# 9     0.619189
# 10    0.675479
# 11    0.731769
# 12    0.788058
# 13    0.844348
# Name:  Max Link Utilization, dtype: float64

# %%
np.std(df[" Max Link Utilization"][:14])
# Out:
# 0.15761901820692611

# %%
df = pd.read_csv("dplr-best-attempt/one_solutions/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df
# Out:
#    Network     Traffic  Demand Scale   TE       TP  Max Link Utilization  \
# 26  Campus  background           0.1  mcf  Doppler              0.192870
# 17  Campus  background           0.2  mcf  Doppler              0.385741
# 11  Campus  background           0.3  mcf  Doppler              0.578611
# 14  Campus  background           0.4  mcf  Doppler              0.771482
# 21  Campus  background           0.5  mcf  Doppler              0.482176
# 25  Campus  background           0.6  mcf  Doppler              0.578611
# 0   Campus  background           0.7  mcf  Doppler              0.675046
# 29  Campus  background           0.8  mcf  Doppler              0.771482
# 10  Campus  background           0.9  mcf  Doppler              0.578611
# 18  Campus  background           1.0  mcf  Doppler              0.642901
# 28  Campus  background           1.1  mcf  Doppler              0.707191
# 15  Campus  background           1.2  mcf  Doppler              0.771482
# ...

# %%
sns.set(rc={'figure.figsize':(8, 5)})
sns.lineplot(df, x="Demand Scale", y="Max Link Utilization", marker='o', markersize=10, markerfacecolor='red')
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Max Link Utilization'>

# %%
sns.set(rc={'figure.figsize':(8, 5)})
sns.lineplot(df, x="Demand Scale", y="Doppler MLU", marker='o', markersize=10, markerfacecolor='red')
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Doppler MLU'>

# %%
import matplotlib.dates as md

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})
sns.lineplot(df, x="Demand Scale", y="Optimization Time", marker='o', markersize=10, markerfacecolor='red')

ax.yaxis.set_major_locator(md.SecondLocator(bysecond = [0, 60]))
# ax.yaxis.set_ticklabels(md.DateFormatter('%M:%S'))

ax.yaxis.set_major_formatter(md.DateFormatter('%M:%S'))

# %%
import matplotlib.dates as md

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})
sns.lineplot(df, x="Demand Scale", y="Optimization Time", marker='o', markersize=10, markerfacecolor='red')

# ax.yaxis.set_major_locator(md.SecondLocator(bysecond = [0, 60]))
ax.yaxis.set_ticklabels(md.DateFormatter('%M:%S'))

# ax.yaxis.set_major_formatter(md.DateFormatter('%M:%S'))

# %%
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Max Link Utilization", markers=True)
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Max Link Utilization'>

# %%
df_3 = pd.read_csv("/home/mhall7/durairajanlab.matt/topology-programming/data/results/Campus_mcf-Doppler-Campus-background-0.1_2__-mcf/Campus_0-0-1_1_0_0_0_Gbps_0.1/DopplerMLU.dat", delimiter="\t")

# %%
files = [f"/home/mhall7/durairajanlab.matt/topology-programming/data/results/Campus_mcf-Doppler-Campus-background-{i/10}_2__-mcf/Campus_0-0-1_1_0_0_0_Gbps_{i/10}/DopplerMLU.dat" for i in range(1,31)]

# %%
files = [f"/home/mhall7/durairajanlab.matt/topology-programming/data/results/Campus_mcf-Doppler-Campus-background-{i/10}_2__-mcf/Campus_0-0-1_1_0_0_0_Gbps_{i/10}/DopplerMLU.dat" for i in range(1,31)]
dfs = [pd.read_csv(f, delimiter='\t') for f in files]

# %%
dfs[0]["Max Link Util"]
# Out:
# 0    0.207000
# 1    0.207000
# 2    0.051750
# 3    0.029714
# Name: Max Link Util, dtype: float64

# %%
plt.clf()
fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(18, 5)})

# sns.boxplot(dfs[0]["Max Link Util"])
sns.boxplot([dfs[i]["Max Link Util"] for i in range(30)])

ax.set_xticklabels([str((i+1)/10) for i in range(30)])
ax.set_xlabel("Demand Scale")
ax.set_ylabel("Max Link Utilization")
# ax.set_yticks([i/10 for i in range(11)])
# [dfs[i]["Max Link Util"] for i in range(20)]
# Out:
# Text(0, 0.5, 'Max Link Utilization')

# %%
sns.set(rc={'figure.figsize':(3, 5)})
MLU_list = [dfs[j]["Max Link Util"] for j in range(len(dfs))]
# for i in range(20):
#     sns.violinplot([dfs[j]["Max Link Util"][i] for j in range(len(dfs))])

# %%
MLU_list
# Out:
# [0    0.207
#  Name: Max Link Util, dtype: float64,
#  0    0.437
#  Name: Max Link Util, dtype: float64,
#  0    0.668
#  Name: Max Link Util, dtype: float64,
#  0    0.894
#  Name: Max Link Util, dtype: float64,
#  0    0.561
#  Name: Max Link Util, dtype: float64,
#  0    0.6765
#  Name: Max Link Util, dtype: float64,
#  0    0.7885
#  Name: Max Link Util, dtype: float64,
#  0    0.904
#  Name: Max Link Util, dtype: float64,
#  0    0.679
#  Name: Max Link Util, dtype: float64,
#  0    0.754333
#  Name: Max Link Util, dtype: float64,
#  0    0.831
#  Name: Max Link Util, dtype: float64,
#  0    0.908
#  Name: Max Link Util, dtype: float64,
#  0    0.982667
#  Name: Max Link Util, dtype: float64,
#  0    0.794
#  Name: Max Link Util, dtype: float64,
#  0    0.8515
#  Name: Max Link Util, dtype: float64,
#  0    0.9085
#  Name: Max Link Util, dtype: float64,
#  0    0.9655
#  Name: Max Link Util, dtype: float64,
#  0    0.8184
#  Name: Max Link Util, dtype: float64,
#  0    0.8638
# ...

# %%
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df
# Out:
# /tmp/ipykernel_3512952/2300908988.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/gpfs/projects/durairajanlab/mhall7/topology-programming/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Max Link Utilization", marker='o', markersize=10, markerfacecolor='red')
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Max Link Utilization'>

# %%
sns.lineplot(df, x="Demand Scale", y="Doppler MLU", marker='o', markersize=10, markerfacecolor='red')
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Doppler MLU'>

# %%
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Optimization Time", marker='o', markersize=10, markerfacecolor='red')
ax.set_ylabel("Optimization Time (s)")
ax.set_ylim(0, 100)
# Out:
# (0.0, 100.0)

# %%
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Total Solutions", marker='o', markersize=10, markerfacecolor='red')
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Total Solutions'>

# %%
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Doppler MLU", marker='o', markersize=10, markerfacecolor='red')
# Out:
# <Axes: xlabel='Demand Scale', ylabel='Doppler MLU'>

# %%
from datetime import timedelta

df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Optimization Time", marker='o', markersize=10, markerfacecolor='red')
ax.set_ylabel("Optimization Time\n(hh:mm:ss)")
ax.set_yscale('log')

y = [100, 1000, 10000, 100000]
y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

ax.set_yticks(y,y_timedelta)

# %%
from datetime import timedelta
from matplotlib.ticker import PercentFormatter
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Doppler Min MLU", marker='o', markersize=10, markerfacecolor='red')
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
from datetime import timedelta
from matplotlib.ticker import PercentFormatter
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Max Link Utilization", marker='o', markersize=10, markerfacecolor='red')
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
from datetime import timedelta
from matplotlib.ticker import PercentFormatter
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Max Link Utilization", marker='o', markersize=10, markerfacecolor='red')
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
from datetime import timedelta
from matplotlib.ticker import PercentFormatter
df = pd.read_csv("data/reports/mcf-Doppler-Campus-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Doppler Min MLU", marker='o', markersize=10)
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
plt.title("Campus base topology")

ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
from datetime import timedelta
from matplotlib.ticker import PercentFormatter
df = pd.read_csv("data/reports/mcf-Doppler-four-node-background.csv")
df = df.sort_values(by=['Demand Scale'])
df

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Doppler Min MLU", marker='o', markersize=10, hue="Optimization")
plt.title("Linear, four-node base topology")
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
csvString = """Network,Traffic,Demand Scale,TE,TP,Max Link Utilization,Loss,Throughput,Total Solutions,Doppler Min MLU,Optimization Time,Topology ID,Optimal Topology ID
Campus,background,0.1,mcf,Doppler,0.19287,0.0,1.0,5,0.228,161.984931189,b'DyB87HgO10M=',b'CwDsvHgM10M='
Campus,background,0.2,mcf,Doppler,0.385741,0.0,1.0,91,0.456,300.347328454,b'NQCw4eIzvEM=',b'agBA50VrqEM='
Campus,background,0.3,mcf,Doppler,0.578611,0.0,1.0,8,0.685,179.35313181200002,b'jyB87HgO10M=',b'PQDg4+GxvEM='
Campus,background,0.4,mcf,Doppler,0.385741,0.0,1.0,4,0.456,180.26149358299998,b'SBTBg/a/10M=',b'DwB87HgO10M='
Campus,background,0.5,mcf,Doppler,0.241088,0.0,1.0,60,0.57,360.808333807,b'H0H42PEYz0M=',b'D4D8fHgM1kM='
Campus,background,0.6,mcf,Doppler,0.578611,0.0,1.0,58,0.685,442.79151198399995,b'PYLwseMxvEM=',b'PYLwseMxvEM='
Campus,background,0.7,mcf,Doppler,0.675046,0.0,1.0,3,0.799,203.950621402,b'nSQBB/17z0M=',b'HwD42PEYz0M='
Campus,background,0.8,mcf,Doppler,0.528669,0.0,1.0,5,0.609,243.88414592799998,b'CA3Bw/o/3kM=',b'DhDotHgs10M='
Campus,background,0.9,mcf,Doppler,0.64678,0.0,1.0,4,0.685,179.906151797,b'TuPg4fg/3kM=',b'DwCcXXwM10M='
Campus,background,1.0,mcf,Doppler,0.642901,0.0,1.0,5,0.761,204.104641116,b'jyB87HgO10M=',b'nwB4ufBYzkM='
Campus,background,1.1,mcf,Doppler,0.544023,0.0,1.0,3,0.628,196.248785274,b'JgTQQuO9vEM=',b'LiHYrHgM10M='
Campus,background,1.2,mcf,Doppler,0.578611,0.0,1.0,3,0.685,220.54962710200002,b'Dow81HgM10M=',b'Dow81HgM10M='
Campus,background,1.3,mcf,Doppler,0.626829,0.0,1.0,64,0.742,809.550079603,b'C4BotPgc10M=',b'H0H42PEYz0M='
Campus,background,1.4,mcf,Doppler,0.675046,0.0,1.0,5,0.799,224.56343787199998,b'nZGBhfV7z0M=',b'H4CwqfQZzkM='
Campus,background,1.5,mcf,Doppler,0.689799,0.0,1.0,5,0.685,232.06386576,b'XcGBA/17z0M=',b'OoAhB+OzvEM='
Campus,background,1.6,mcf,Doppler,0.617185,0.0,1.0,3,0.73,231.234104098,b'HhFZ8/AYzkM=',b'HhFZ8/AYzkM='
Campus,background,1.7,mcf,Doppler,0.735291,0.0,1.0,7,0.776,354.981867315,b'bFTwwPS/10M=',b'WwGkRdNnqUM='
Campus,background,1.8,mcf,Doppler,0.578611,0.0,1.0,4,0.685,187.77954754,b'zL/g4fi93kM=',b'SYA59XgO10M='
Campus,background,1.9,mcf,Doppler,0.682712,0.0,1.0,3,0.723,212.660604831,b'J2L4zHgu10M=',b'XST4afFYzUM='
Campus,background,2.0,mcf,Doppler,0.718644,0.0,1.0,3,0.761,195.025944566,b'zqjgwfo/3kM=',b'RoK01Pgs10M='
Campus,background,2.1,mcf,Doppler,0.69623,0.0,1.0,44,0.799,684.6172778739999,b'TIG5yfEaz0M=',b'I4D5rHgu10M='
Campus,background,2.2,mcf,Doppler,0.951553,0.0,1.0,5,0.717,240.316503411,b'XSB6ivlYz0M=',b'DxFVdPgu10M='
Campus,background,2.3,mcf,Doppler,0.684638,0.0,1.0,16,0.75,412.944212527,b'b+F4rHg+10M=',b'TYVsungN10M='
Campus,background,2.4,mcf,Doppler,0.742128,0.0,1.0,19,0.783,378.836244476,b'OoX1EOP1vkM=',b'TSDwjH4e10M='
Campus,background,2.5,mcf,Doppler,0.794376,0.0,1.0,7,0.713,197.40497840199998,b'rXA92Hg+10M=',b'C2JtsHoe10M='
Campus,background,2.6,mcf,Doppler,1.124563,0.086074,0.913926,6,0.742,289.337066694,b'GDtZsfF8zkM=',b'LpO4zHwc10M='
Campus,background,2.7,mcf,Doppler,0.778544,0.0,1.0,5,0.77,183.501621705,b'ieGtnHg+10M=',b'G4l5OPF4z0M='
Campus,background,2.8,mcf,Doppler,0.750849,0.0,1.0,5,0.799,227.80859203,b'K2XwTHw+10M=',b'TwjhOfg6z0M='
Campus,background,2.9,mcf,Doppler,0.866492,0.0,1.0,16,0.735,402.041247319,b'pzzYbHg+10M=',b'LfPgkeP5vEM='
Campus,background,3.0,mcf,Doppler,0.935876,0.0,1.0,20,0.763,711.4134625659999,b'S2vwnHg+10M=',b'SR7wnngu10M='"""

csvStringIO = StringIO(csvString)

df = pd.read_csv(csvStringIO,  sep=",")

from datetime import timedelta
from matplotlib.ticker import PercentFormatter

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Doppler Min MLU", marker='o', markersize=10)
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
# plt.title("Campus base topology")

ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Total Solutions", marker='o', markersize=10)
plt.title("UO Network")
# ax.set_ylabel("Optimization Time (hh:mm:ss)")

# ax.set_ylim(0, 1)
# ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)
# Out:
# Text(0.5, 1.0, 'UO Network')

# %%
df
# Out:
#    Network     Traffic  Demand Scale   TE       TP  Max Link Utilization  \
# 0   Campus  background           0.1  mcf  Doppler              0.192870
# 1   Campus  background           0.2  mcf  Doppler              0.385741
# 2   Campus  background           0.3  mcf  Doppler              0.578611
# 3   Campus  background           0.4  mcf  Doppler              0.385741
# 4   Campus  background           0.5  mcf  Doppler              0.241088
# 5   Campus  background           0.6  mcf  Doppler              0.578611
# 6   Campus  background           0.7  mcf  Doppler              0.675046
# 7   Campus  background           0.8  mcf  Doppler              0.528669
# 8   Campus  background           0.9  mcf  Doppler              0.646780
# 9   Campus  background           1.0  mcf  Doppler              0.642901
# 10  Campus  background           1.1  mcf  Doppler              0.544023
# 11  Campus  background           1.2  mcf  Doppler              0.578611
# ...

# %%
csvString = """
Network,Traffic,Demand Scale,TE,TP,Max Link Utilization,Loss,Throughput,Total Solutions,Doppler Min MLU,Optimization Time,Topology ID,Optimal Topology ID
Regional,background,0.1,mcf,Doppler,0.135029,0.0,1.0,59,0.142,115.222617454,b'AIDOeR4+f0I=',b'AIDOeR4+f0I='
Regional,background,0.2,mcf,Doppler,0.270057,0.0,1.0,60,0.285,316.64229374800004,b'AIDOeR4ef0I=',b'AIDOeR4ef0I='
Regional,background,0.3,mcf,Doppler,0.405086,0.0,1.0,47,0.428,135.22922818599994,b'AIDOeR4+f0I=',b'AIDOeR4+f0I='
Regional,background,0.4,mcf,Doppler,0.540114,0.0,1.0,81,0.571,74.554806729,b'AIDOeR4+f0I=',b'AIDOeR4+f0I='
Regional,background,0.5,mcf,Doppler,0.675143,0.0,1.0,61,0.714,174.14998574600008,b'AIDOeR4+f0I=',b'AIDOeR4+f0I='
Regional,background,0.6,mcf,Doppler,0.540114,0.0,1.0,70,0.571,337.24907926000003,b'AMDOeR4+f0I=',b'AMDOeR4+f0I='
Regional,background,0.7,mcf,Doppler,0.630133,0.0,1.0,70,0.667,121.19291561599994,b'AIDOeT4+f0I=',b'AIDOeT4+f0I='
Regional,background,0.8,mcf,Doppler,0.720153,0.0,1.0,68,0.762,186.8370243390002,b'AIDMeR49f0I=',b'AIDOex4+f0I='
Regional,background,0.9,mcf,Doppler,0.607629,0.0,1.0,76,0.643,288.3048676819999,b'AMDOeT4+f0I=',b'AMDOeT4+f0I='
Regional,background,1.0,mcf,Doppler,0.700266,0.0,1.0,74,0.714,291.1718448180002,b'AIDPWxYkf0I=',b'AIDOez4+f0I='
Regional,background,1.1,mcf,Doppler,0.742657,0.0,1.0,71,0.786,295.0758045280004,b'AIDG+R4/f0I=',b'AMDO+R4+f0I='
Regional,background,1.2,mcf,Doppler,0.648137,0.0,1.0,67,0.686,789.4745671420001,b'AODGeRa7f0I=',b'AODGeRa7f0I='
Regional,background,1.3,mcf,Doppler,0.702149,0.0,1.0,61,0.743,702.3396719719999,b'AIDMe14/f0I=',b'AIDce14+f0I='
Regional,background,1.4,mcf,Doppler,0.740726,0.0,1.0,75,0.667,1946.8889646569996,b'AIDR+Ug+f0I=',b'AIDW8d4+f0I='
Regional,background,1.5,mcf,Doppler,0.683096,0.0,1.0,70,0.714,2285.8228250889997,b'AIDHczy2f0I=',b'AMDHeT4/f0I='
Regional,background,1.6,mcf,Doppler,0.727686,0.0,1.0,62,0.762,938.9706525469992,b'AMDP+R6uf0I=',b'AMDP+R6uf0I='
Regional,background,1.7,mcf,Doppler,0.655853,0.0,1.0,67,0.694,5215.521419219,b'ANDseb4uf0I=',b'ANDMfb4uf0I='
Regional,background,1.8,mcf,Doppler,0.697947,0.0,1.0,78,0.735,2566.8536257220003,b'AMDN+V6uf0I=',b'AMDN+V6uf0I='
Regional,background,1.9,mcf,Doppler,0.734239,0.0,1.0,57,0.776,5900.988914242,b'AMDkfd4+f0I=',b'AODkdX4+f0I='
Regional,background,2.0,mcf,Doppler,0.675143,0.0,1.0,38,0.714,5951.1013536909995,b'AMDmeb5ff0I=',b'AMDk+d4/f0I='
Regional,background,2.1,mcf,Doppler,0.7089,0.0,1.0,48,0.75,3949.9716773630025,b'AMDu2b6ef0I=',b'AMDu2b6ef0I='
Regional,background,2.2,mcf,Doppler,0.854937,0.0,1.0,34,0.786,2597.7017362450024,b'AMCuuV74f0I=',b'AMDu8V+ef0I='
Regional,background,2.3,mcf,Doppler,0.723536,0.0,1.0,42,0.758,4065.107491224,b'AMDusf6uf0I=',b'AMDu8f6Of0I='
Regional,background,2.4,mcf,Doppler,0.757242,0.0,1.0,29,0.791,2547.9137526339982,b'AMDkfd+8f0I=',b'AMDkfd+8f0I='
Regional,background,2.5,mcf,Doppler,0.878073,0.0,1.0,7,0.894,132.332506674,b'AMDPcX9uf0I=',b'AMDP8X6uf0I='
Regional,background,2.6,mcf,Doppler,0.881921,0.0,1.0,8,0.929,126.31518668599999,b'AMDkfd8+f0I=',b'AMDkfd8+f0I='
Regional,background,2.7,mcf,Doppler,1.016751,0.015549,0.984451,3,0.965,40.633052106,b'AID8eX9cf0I=',b'AID8eX9cf0I='
Regional,background,2.8,mcf,Doppler,0.880827,0.0,1.0,5,0.922,150.824335055,b'AMDmef7af0I=',b'AMDmef7af0I='
Regional,background,2.9,mcf,Doppler,0.919766,0.0,1.0,1,0.999,89.485839239,b'AID8e/6Of0I=',b'AID8e/6Of0I='
Regional,background,3.0,mcf,Doppler,0.943743,0.0,1.0,1,0.991,59.12451098,b'AMDsff6Of0I=',b'AMDsff6Of0I='
"""

csvStringIO = StringIO(csvString)

df = pd.read_csv(csvStringIO,  sep=",")

from datetime import timedelta
from matplotlib.ticker import PercentFormatter

fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Doppler Min MLU", marker='o', markersize=10)
# ax.set_ylabel("Optimization Time (hh:mm:ss)")
# plt.title("Campus base topology")

ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)

# %%
df
# Out:
#      Network     Traffic  Demand Scale   TE       TP  Max Link Utilization  \
# 0   Regional  background           0.1  mcf  Doppler              0.135029
# 1   Regional  background           0.2  mcf  Doppler              0.270057
# 2   Regional  background           0.3  mcf  Doppler              0.405086
# 3   Regional  background           0.4  mcf  Doppler              0.540114
# 4   Regional  background           0.5  mcf  Doppler              0.675143
# 5   Regional  background           0.6  mcf  Doppler              0.540114
# 6   Regional  background           0.7  mcf  Doppler              0.630133
# 7   Regional  background           0.8  mcf  Doppler              0.720153
# 8   Regional  background           0.9  mcf  Doppler              0.607629
# 9   Regional  background           1.0  mcf  Doppler              0.700266
# 10  Regional  background           1.1  mcf  Doppler              0.742657
# ...

# %%
fig, ax = plt.subplots()
sns.set(rc={'figure.figsize':(8, 5)})

sns.lineplot(df, x="Demand Scale", y="Total Solutions", marker='o', markersize=10)
plt.title("Link Oregon")
# ax.set_ylabel("Optimization Time (hh:mm:ss)")

# ax.set_ylim(0, 1)
# ax.yaxis.set_major_formatter(PercentFormatter(1.0))
# ax.set_yscale('log')

# y = [100, 1000, 10000, 100000]
# y_timedelta = [str(timedelta(seconds=int(s))) for s in y]

# ax.set_yticks(y,y_timedelta)
# Out:
# Text(0.5, 1.0, 'Link Oregon')
